# %% [markdown]
# ![image.png](attachment:619e432d-2d82-420c-a154-ccfb7c5b540f.png)

# %% [markdown]
# <div dir="rtl" style="text-align:center; font-family: 'B Nazanin'; font-size: 24px;">
#     <div class="alert alert-block alert-info">
#         <h1>» Chapter One: Intro«</h1>
#
# </div>
# </div>

# %% [markdown]
# ![Assembly-language.jpg](attachment:44d4e196-9064-496b-9b04-70047966687e.jpg)

# %% [markdown]
# ![Motorola_6800_Assembly_Language.png](attachment:53fc960f-b08d-4791-87db-622e5cc9eafa.png)

# %% [markdown]
# ![slide_10.jpg](attachment:9155500a-5ccc-4fda-b311-981cf1a4ff64.jpg)

# %% [markdown]
# ![classification-of-programming-language.png](attachment:15d2b227-dd81-4830-acb7-23031ffb8c4f.png)

# %% [markdown]
# ![nyo2w5v9jmgtn3un9be8.png](attachment:4705c786-2a2e-44cb-b1e1-33797cfbf0c8.png)

# %% [markdown]
# ![download.png](attachment:e39dd3ec-0741-44aa-baf2-75de363825e5.png)

# %% [markdown]
# <div dir="rtl" style=" font-family: 'B Nazanin'; font-size: 24px;">
#     <div class="alert alert-block alert-warning">
#         <h3> ویژگیهای پایتون</h3>
#             <ul>
#         <li><h3>مفسری</h3></li>
#         <li><h3>سطح بالا</h3></li>
#         <li><h3>ساده برای یادگیری</h3></li>
#         <li><h3>جامعه برنامه نویسی بزرگ</h3></li>
#         <li><h3>استفاده شده در پروژه های بزرگ</h3></li>
#         <li><h3> Free & opensource</h3></li>
#         <li><h3>کتابخونه های کاربردی</h3></li>
#         <li><h3>قابل حمل</h3></li>
#         <li><h3>توسعه پذیری و تعبیه پذیری</h3></li>
#         <li><h3>همه منظوره بودن</h3></li>
#
# <ul>
# <li><h3>موتور جستجوگر گوگل و موتور گرافیکی یوتیوب</h3></li>
# <li><h3>ساخت برنامه های کاربردی علمی در سازمان فضایی ناسا، Fermila</h3></li>
# <li><h3>بخشی از سرویس ایمیل یاهو</h3></li>
# <li><h3>Cisco  ,Intel ،IBM  تست سخت افزار</h3></li>
# <li><h3>ابزارهای نصب لینوکس </h3></li>
# <li><h3>Cisco  ,Intel ،IBM  تست سخت افزار</h3></li>
# </ul>
#     </ul>
#
# </div>
# </div>

# %% [markdown]
# ![image.png](attachment:ff98b0d1-7fb3-4650-8c32-46f17d6513e4.png)

# %% [markdown]
# <div dir="rtl" style=" font-family: 'B Nazanin'; font-size: 24px;">
#     <div class="alert alert-block alert-warning">
#         <h3>الگوریتم چیست؟</h3>
#         <h4>به تعریف گام به گام یک عملیات برای حل یک مساله با تقدم و تاخر مشخص که متناهی بوده و از یک نقطه شروع و در نقطه ای دیگر به پایان میرسند و ممکن است چندین بار تکرار شوند الگوریتم گفته می شود.</h4>
#     </div>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:center; font-family: 'B Nazanin'; font-size: 24px;">
#     <div class="alert alert-block alert-info">
#         <h1>» فصل دوم: نصب و شروع به کار «</h1>
#         <p>(20دقیقه)</p>
#     </div>
# </div>

# %% [markdown]
# <div dir="rtl" style=" font-family: 'B Nazanin'; font-size: 24px;">
#     <div class="alert alert-block alert-warning">
#         <h3> نصب و راه اندازی پایتون</h3>
#             <ul>
#         <li><h3>دانلود پایتون : سایت اصلی و ایرانی</h3></li>
#         <li><h3>IDLE Python</h3></li>
#                 <li><h3>IPython</h3></li>
#         <li><h3>version & cwd & executable </h3></li>
#         <li><h3>CMD & PowerShell & Terminal</h3></li>
#         <li><h3>notepad</h3></li>
#         <li><h3>IDE, PyCharm</h3></li>
#         <li><h3>CodeEditor, VSCode</h3></li>
#         <li><h3>NoteBooks, Jupyter Notebook</h3></li>
#                 <li><h3>Online Web</h3></li>
#                 <li><h3>Mobile</h3></li>
#     </ul>
#
# </div>
# </div>

# %% [markdown]
# ![images.jfif](attachment:1609a75e-2244-421a-89cf-eb183c2eaffb.jfif)

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> مشاهده محل مفسر در کامپیوتر شما</div>

# %%
python --version

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\mehrab\AppData\Local\Programs\Python\Python312\python.exe

# %% [markdown]
# ##  <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> مشاهده پوشه کار یا working directory پروژه</div>

# %%
import os
print(os.getcwd())
